# %% [markdown]
# # Country-level risk assessment
#
# In this notebook, we will perform a **risk assessmente** for all available CI data within a country. The assessment is based on combining hazard data (e.g., flood depths) with OpenStreetMap feature data.
#
# We will follow the steps outlined below to conduct the assessment:
#
# 1. **Loading the necessary packages:**
#    We will import the Python libraries required for data handling, analysis, and visualization.
#
# 2. **Loading the data:**
#    The infrastructure data (e.g., roads) and hazard data (e.g., flood depths) will be loaded into the notebook.
#
# 3. **Preparing the data:**
#    The infrastructure and hazard data will be processed and data gaps can be filled, if required.
#
# 4. **Performing the risk assessment:**
#    We will overlay the hazard data with the feature information.
#
# 5. **Visualizing the results:**
#    Finally, we will visualize the estimated exposure using graphs and maps.

# %% [markdown]
# ## 1. Loading the Necessary Packages
# To perform the assessment, we are going to make use of several [python packages](https://docs.python.org/3/tutorial/modules.html#packages).
#
# In case you run this in Google Colab, you will have to install the packages below **(remove the hashtag in front of them)**.

# %%
#!pip install damagescanner==0.9b4
#!pip install contextily
#!pip install exactextract
#!pip install osm-flex

# %% [markdown]
# In this step, we will import all the required Python libraries for data manipulation, spatial analysis, and visualization.

# %%
import os,sys
import rasterio
import shapely
import traceback
import warnings
import xarray as xr
import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns

from tqdm import tqdm

from pathlib import Path
import matplotlib.pyplot as plt
import rioxarray
import contextily as cx

from osm_flex import download
from exactextract import exact_extract
from damagescanner.core import DamageScanner
from damagescanner.base_values import DICT_CIS_VULNERABILITY_FLOOD


warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Specify the country of interest

# %% [markdown]
# Before we continue, we should specify the country for which we want to assess the damage. We use the ISO3 code for the country to download the OpenStreetMap data.

# %%
country_full_name = 'Belize'
country_iso3 = 'BLZ'

# %% [markdown]
# ## 2. Loading the Data
# In this step, we will prepare and load two key datasets:
#
# 1. **Infrastructure data:**
#    This dataset contains information on the location and type of infrastructure (e.g., roads). Each asset may have attributes such as type, length, and replacement cost.
#
# 2. **Hazard data:**
#    This dataset includes information on the hazard affecting the infrastructure (e.g., flood depth at various locations).

# %% [markdown]
# ### Infrastructure Data
#
# We will perform this example analysis for Jamaica. To start the analysis, we first download the OpenStreetMap data from GeoFabrik.

# %%
infrastructure_path = download.get_country_geofabrik(country_iso3)

# %% [markdown]
# We will not load the data directly, we will let the code itself read the information. It is important, however, to specificy which infrastructure systems you want to include. We do so in the list below:

# %%
asset_types = [
        "roads",
        "rail",
        "air",
        "telecom",
        "water_supply",
        "waste_solid",
        "education",
        "healthcare",
        "power",
        "wastewater",
    ]

# %% [markdown]
# ### Vulnerability data
# We will collect all the vulnerability curves for each of the asset types. Important to note is that national or local-scale analysis requires a thorough check which curves can and should be used!

# %%
vulnerability_path = "https://zenodo.org/records/10203846/files/Table_D2_Multi-Hazard_Fragility_and_Vulnerability_Curves_V1.0.0.xlsx?download=1"

vul_df = pd.read_excel(vulnerability_path,sheet_name='F_Vuln_Depth')

# %%
damage_curves_all_ci = {}
for ci_type in DICT_CIS_VULNERABILITY_FLOOD:

    ci_system = DICT_CIS_VULNERABILITY_FLOOD[ci_type]
    
    selected_curves = []
    for subtype in ci_system:
        selected_curves.append(ci_system[subtype][0])
    
    damage_curves = vul_df[['ID number']+selected_curves]
    damage_curves = damage_curves.iloc[4:125,:]
    damage_curves.set_index('ID number',inplace=True)
    damage_curves.index = damage_curves.index.rename('Depth')  
    damage_curves = damage_curves.astype(np.float32)
    damage_curves.columns = list(ci_system.keys())
    damage_curves = damage_curves.fillna(method='ffill')

    # Make sure we set the index of the damage curves (the inundation depth) in the same metric as the hazard data (e.g. meters or centimeters).
    damage_curves.index = damage_curves.index*100

    damage_curves_all_ci[ci_type] = damage_curves

# %% [markdown]
# ### Maximum damages
# One of the most difficult parts of the assessment is to define the maximum reconstruction cost of particular assets. As such, we sometimes may want to run the analysis without already multiplying the results with those costs. To do so, we simply set all the maximum damage values to 1:

# %%
MAXDAM_DICT = {
    
    "roads": {
                "motorway" : 2000,
                "motorway_link" :  2000,
                "trunk" : 2000,
                "trunk_link" :  2000,
                "primary" :  2000,
                "primary_link": 2000,
                "secondary" : 1300,
                "secondary_link" :  1300,
                "tertiary" :  700,
                "tertiary_link" : 700,
                "residential" :  300,
                "road" :  300,
                "unclassified" :  300,
                "track" : 300,
                "service" : 300,
    
        },

    "rail": {
        'rail' : 2500,
    },

    "air": { 
        "aerodrome" : 850,
        "terminal" : 1000,
        "runway" : 700,},

    "telecom": { # curves beschikbaar voor overstromingen
        "mast" : 100000, #entire unit
        "communications_tower" :100000, #entire unit,
        },

    "water_supply": { 
                "water_works" : 1000, # m2,
                "water_well": 1000, # m2,
                "water_tower": 100000, #entire unit,
                "reservoir_covered": 0,
                "storage_tank": 25000, #entire unit,
        },

    "waste_solid": {
            "waste_transfer_station" : 1000, # m2,
            },

    "education": { 
            "school" : 1100,
            "kindergarten" : 1100,
            "college": 1100,
            "university": 1100, 
            "library": 1100,


        },

    "healthcare": { # curves beschikbaar voor overstromingen
                "hospital" : 1100,
                "clinic" : 1100,
                "doctors" : 1100,
                "pharmacy" : 1100,
                "dentist" :1100,
                "physiotherapist" : 1100,
                "alternative" : 1100,
                "laboratory" : 1100,
                "optometrist" : 1100,
                "rehabilitation" : 1100,
                "blood_donation" : 1100,
                "birthing_center" : 1100,
        },

    "power": {
                "line" : 250, #m 
                "cable" : 250, #m 
                "minor_line" : 250, #m 
                "plant" : 5000 , #m2
                "generator" : 5000 , #m2
                "substation" : 5000 , #m2
                "transformer" : 5000 , #m2
                "pole" : 100000, #entire unit,
                "portal" :  5000 , #m2
                "tower" : 100000, #entire unit,
                "terminal" :  5000 , #m2
                "switch" :  5000 , #m2
                "catenary_mast" : 100000, #entire unit,
        },


    "wastewater": {
            "wastewater_plant" : 2500, #m2,
            "waste_transfer_station": 1000, #m2, 
        },

}

# %%
maxdam_all_ci = {}
for ci_type in MAXDAM_DICT:
    maxdam_dict = MAXDAM_DICT[ci_type]
    maxdam = pd.DataFrame.from_dict(maxdam_dict,orient='index').reset_index()
    maxdam.columns = ['object_type','damage']
    maxdam_all_ci[ci_type] =  maxdam

# %% [markdown]
# ### Hazard Data
# For this example, we make use of the flood data provided by [CDRI](https://giri.unepgrid.ch/map?list=explore).
#
# We use a 1/100 flood map to showcase the approach.

# %%
hazard_map = xr.open_dataset("https://hazards-data.unepgrid.ch/global_pc_h100glob.tif", engine="rasterio")

# %% [markdown]
# ### Ancilliary data for processing

# %%
world = gpd.read_file("https://github.com/nvkelso/natural-earth-vector/raw/master/10m_cultural/ne_10m_admin_0_countries.shp")
world_plot = world.to_crs(3857)

# %% [markdown]
# ## 3. Preparing the Data

# %% [markdown]
# Clip the hazard data to the country of interest.

# %%
country_bounds = world.loc[world.ADM0_ISO == country_iso3].bounds
country_geom = world.loc[world.ADM0_ISO == country_iso3].geometry

# %%
country_box = shapely.box(country_bounds.minx.values,country_bounds.miny.values,country_bounds.maxx.values,country_bounds.maxy.values)[0]

# %% [markdown]
# Set the return periods and download the hazard data

# %%
return_periods = [2,5,10,50,100,200,500,1000]

hazard_dict = {}
for return_period in return_periods:
    hazard_map = xr.open_dataset(f"https://hazards-data.unepgrid.ch/global_pc_h{return_period}glob.tif", engine="rasterio")

    hazard_dict[return_period] = hazard_map.rio.clip_box(minx=country_bounds.minx.values[0],
                     miny=country_bounds.miny.values[0],
                     maxx=country_bounds.maxx.values[0],
                     maxy=country_bounds.maxy.values[0]
                    )

# %% [markdown]
# ## 4. Performing the Risk Assessment
# We will use the DamageScanner approach. This is a fully optimised exposure, vulnerability damage and risk calculation method, that can capture a wide range of inputs to perform such an assessment.

# %%
save_asset_risk_results = {}
for asset_type in asset_types:
        save_asset_risk_results[asset_type] = DamageScanner(hazard_dict[2], 
                                                       infrastructure_path, 
                                                       curves=damage_curves_all_ci[asset_type], 
                                                       maxdam=maxdam_all_ci[asset_type]
                                                           ).risk(hazard_dict,
            asset_type=asset_type
        )
# Out:
# Risk Calculation:   0%|                                                                          | 0/8 [00:00<?, ?it/s]
# Overlay raster with vector:   0%|                                                               | 0/18 [00:00<?, ?it/s]
# Overlay raster with vector:   6%|███                                                    | 1/18 [00:00<00:06,  2.54it/s]
# Overlay raster with vector:  11%|██████                                                 | 2/18 [00:02<00:18,  1.18s/it]
# Overlay raster with vector:  17%|█████████▏                                             | 3/18 [00:17<01:58,  7.88s/it]
# Overlay raster with vector:  22%|████████████▏                                          | 4/18 [00:18<01:12,  5.16s/it]
# Overlay raster with vector:  28%|███████████████▎                                       | 5/18 [00:22<01:00,  4.69s/it]
# Overlay raster with vector:  33%|██████████████████▎                                    | 6/18 [00:23<00:38,  3.17s/it]
# Overlay raster with vector:  39%|█████████████████████▍                                 | 7/18 [00:37<01:14,  6.81s/it]
# Overlay raster with vector:  44%|████████████████████████▍                              | 8/18 [00:43<01:04,  6.44s/it]
# Overlay raster with vector:  50%|███████████████████████████▌                           | 9/18 [00:48<00:54,  6.01s/it]
# Overlay raster with vector:  56%|██████████████████████████████                        | 10/18 [00:55<00:52,  6.53s/it]
# Overlay raster with vector:  61%|█████████████████████████████████                     | 11/18 [00:56<00:32,  4.69s/it]
# Overlay raster with vector:  72%|███████████████████████████████████████               | 13/18 [00:57<00:13,  2.70s/it]
# Overlay raster with vector:  78%|██████████████████████████████████████████            | 14/18 [01:01<00:12,  3.16s/it]
# Overlay raster with vector:  83%|█████████████████████████████████████████████         | 15/18 [01:02<00:07,  2.49s/it]
# Overlay raster with vector: 100%|██████████████████████████████████████████████████████| 18/18 [01:03<00:00,  3.51s/it]
#
# convert coverage to meters:   0%|                                                             | 0/2735 [00:00<?, ?it/s]
# convert coverage to meters:  11%|█████▌                                           | 308/2735 [00:00<00:00, 2758.49it/s]
# convert coverage to meters:  21%|██████████▍                                      | 584/2735 [00:00<00:00, 2294.88it/s]
# convert coverage to meters:  30%|██████████████▋                                  | 817/2735 [00:00<00:00, 2072.31it/s]
# convert coverage to meters:  38%|██████████████████                              | 1027/2735 [00:00<00:00, 1871.13it/s]
# convert coverage to meters:  44%|█████████████████████▎                          | 1216/2735 [00:00<00:00, 1703.92it/s]
# convert coverage to meters:  52%|████████████████████████▉                       | 1424/2735 [00:00<00:00, 1807.68it/s]
# convert coverage to meters:  59%|████████████████████████████▏                   | 1608/2735 [00:00<00:00, 1660.48it/s]
# convert coverage to meters:  66%|███████████████████████████████▉                | 1818/2735 [00:00<00:00, 1708.52it/s]
# convert coverage to meters:  75%|███████████████████████████████████▉            | 2047/2735 [00:01<00:00, 1860.79it/s]
# convert coverage to meters:  85%|████████████████████████████████████████▌       | 2312/2735 [00:01<00:00, 1995.83it/s]
# convert coverage to meters: 100%|████████████████████████████████████████████████| 2735/2735 [00:01<00:00, 1966.80it/s]
#
# Calculating damage:   0%|                                                                     | 0/2735 [00:00<?, ?it/s]
# Calculating damage: 100%|███████████████████████████████████████████████████████| 2735/2735 [00:00<00:00, 13665.24it/s]
# Risk Calculation:  12%|████████▎                                                         | 1/8 [01:08<07:57, 68.19s/it]
# Overlay raster with vector:   0%|                                                               | 0/18 [00:00<?, ?it/s]
# Overlay raster with vector:   6%|███                                                    | 1/18 [00:00<00:05,  3.23it/s]
# Overlay raster with vector:  11%|██████                                                 | 2/18 [00:02<00:18,  1.16s/it]
# Overlay raster with vector:  17%|█████████▏                                             | 3/18 [00:17<01:58,  7.90s/it]
# Overlay raster with vector:  22%|████████████▏                                          | 4/18 [00:18<01:12,  5.17s/it]
# Overlay raster with vector:  28%|███████████████▎                                       | 5/18 [00:22<01:00,  4.63s/it]
# Overlay raster with vector:  33%|██████████████████▎                                    | 6/18 [00:22<00:37,  3.16s/it]
# Overlay raster with vector:  39%|█████████████████████▍                                 | 7/18 [00:37<01:14,  6.76s/it]
# Overlay raster with vector:  44%|████████████████████████▍                              | 8/18 [00:43<01:05,  6.59s/it]
# Overlay raster with vector:  50%|███████████████████████████▌                           | 9/18 [00:48<00:56,  6.25s/it]
# Overlay raster with vector:  56%|██████████████████████████████                        | 10/18 [00:56<00:54,  6.76s/it]
# Overlay raster with vector:  61%|█████████████████████████████████                     | 11/18 [00:57<00:34,  4.87s/it]
# Overlay raster with vector:  72%|███████████████████████████████████████               | 13/18 [00:58<00:14,  2.80s/it]
# Overlay raster with vector:  78%|██████████████████████████████████████████            | 14/18 [01:02<00:13,  3.25s/it]
# Overlay raster with vector:  83%|█████████████████████████████████████████████         | 15/18 [01:03<00:07,  2.57s/it]
# Overlay raster with vector: 100%|██████████████████████████████████████████████████████| 18/18 [01:04<00:00,  3.58s/it]
#
# convert coverage to meters:   0%|                                                             | 0/3215 [00:00<?, ?it/s]
# convert coverage to meters:   9%|████▌                                            | 301/3215 [00:00<00:01, 2743.62it/s]
# convert coverage to meters:  18%|████████▊                                        | 576/3215 [00:00<00:01, 2402.06it/s]
# convert coverage to meters:  25%|████████████▍                                    | 818/3215 [00:00<00:01, 2056.81it/s]
# convert coverage to meters:  32%|███████████████▎                                | 1028/3215 [00:00<00:01, 1739.88it/s]
# convert coverage to meters:  38%|██████████████████                              | 1208/3215 [00:00<00:01, 1572.14it/s]
# convert coverage to meters:  43%|████████████████████▍                           | 1369/3215 [00:00<00:01, 1541.45it/s]
# convert coverage to meters:  47%|██████████████████████▊                         | 1527/3215 [00:00<00:01, 1511.43it/s]
# convert coverage to meters:  53%|█████████████████████████▌                      | 1716/3215 [00:01<00:00, 1572.78it/s]
# convert coverage to meters:  58%|███████████████████████████▉                    | 1875/3215 [00:01<00:00, 1473.91it/s]
# convert coverage to meters:  64%|██████████████████████████████▋                 | 2055/3215 [00:01<00:00, 1521.58it/s]
# convert coverage to meters:  71%|█████████████████████████████████▉              | 2274/3215 [00:01<00:00, 1659.04it/s]
# convert coverage to meters:  78%|█████████████████████████████████████▌          | 2518/3215 [00:01<00:00, 1824.73it/s]
# convert coverage to meters:  85%|█████████████████████████████████████████       | 2747/3215 [00:01<00:00, 1912.27it/s]
# convert coverage to meters:  91%|███████████████████████████████████████████▉    | 2940/3215 [00:01<00:00, 1915.40it/s]
# convert coverage to meters: 100%|████████████████████████████████████████████████| 3215/3215 [00:01<00:00, 1797.33it/s]
#
# Calculating damage:   0%|                                                                     | 0/3215 [00:00<?, ?it/s]
# Calculating damage:  46%|█████████████████████████                              | 1464/3215 [00:00<00:00, 13340.77it/s]
# Calculating damage: 100%|███████████████████████████████████████████████████████| 3215/3215 [00:00<00:00, 13672.27it/s]
# Risk Calculation:  25%|████████████████▌                                                 | 2/8 [02:17<06:54, 69.11s/it]
# Overlay raster with vector:   0%|                                                               | 0/18 [00:00<?, ?it/s]
# Overlay raster with vector:   6%|███                                                    | 1/18 [00:00<00:06,  2.77it/s]
# Overlay raster with vector:  11%|██████                                                 | 2/18 [00:02<00:19,  1.23s/it]
# Overlay raster with vector:  17%|█████████▏                                             | 3/18 [00:18<02:01,  8.08s/it]
# Overlay raster with vector:  22%|████████████▏                                          | 4/18 [00:19<01:14,  5.31s/it]
# Overlay raster with vector:  28%|███████████████▎                                       | 5/18 [00:23<01:02,  4.78s/it]
# Overlay raster with vector:  33%|██████████████████▎                                    | 6/18 [00:23<00:39,  3.28s/it]
# Overlay raster with vector:  39%|█████████████████████▍                                 | 7/18 [00:37<01:14,  6.75s/it]
# Overlay raster with vector:  44%|████████████████████████▍                              | 8/18 [00:43<01:05,  6.54s/it]
# Overlay raster with vector:  50%|███████████████████████████▌                           | 9/18 [00:49<00:55,  6.20s/it]
# Overlay raster with vector:  56%|██████████████████████████████                        | 10/18 [00:57<00:53,  6.73s/it]
# Overlay raster with vector:  61%|█████████████████████████████████                     | 11/18 [00:57<00:33,  4.82s/it]
# Overlay raster with vector:  72%|███████████████████████████████████████               | 13/18 [00:58<00:13,  2.79s/it]
# Overlay raster with vector:  78%|██████████████████████████████████████████            | 14/18 [01:03<00:13,  3.31s/it]
# Overlay raster with vector:  83%|█████████████████████████████████████████████         | 15/18 [01:04<00:07,  2.62s/it]
# Overlay raster with vector: 100%|██████████████████████████████████████████████████████| 18/18 [01:05<00:00,  3.61s/it]
#
# convert coverage to meters:   0%|                                                             | 0/3601 [00:00<?, ?it/s]
# convert coverage to meters:   8%|███▉                                             | 286/3601 [00:00<00:01, 2602.99it/s]
# convert coverage to meters:  15%|███████▍                                         | 547/3601 [00:00<00:01, 2114.99it/s]
# convert coverage to meters:  21%|██████████▍                                      | 763/3601 [00:00<00:01, 2052.72it/s]
# convert coverage to meters:  27%|█████████████▏                                   | 971/3601 [00:00<00:01, 1798.22it/s]
# convert coverage to meters:  32%|███████████████▍                                | 1155/3601 [00:00<00:01, 1680.14it/s]
# convert coverage to meters:  37%|█████████████████▋                              | 1326/3601 [00:00<00:01, 1642.52it/s]
# convert coverage to meters:  41%|███████████████████▉                            | 1492/3601 [00:00<00:01, 1536.03it/s]
# convert coverage to meters:  46%|█████████████████████▉                          | 1647/3601 [00:00<00:01, 1499.47it/s]
# convert coverage to meters:  52%|█████████████████████████                       | 1876/3601 [00:01<00:01, 1673.24it/s]
# convert coverage to meters:  57%|███████████████████████████▎                    | 2045/3601 [00:01<00:01, 1504.48it/s]
# convert coverage to meters:  63%|██████████████████████████████                  | 2252/3601 [00:01<00:00, 1611.12it/s]
# convert coverage to meters:  68%|████████████████████████████████▌               | 2441/3601 [00:01<00:00, 1642.08it/s]
# convert coverage to meters:  74%|███████████████████████████████████▌            | 2668/3601 [00:01<00:00, 1765.31it/s]
# convert coverage to meters:  80%|██████████████████████████████████████▌         | 2891/3601 [00:01<00:00, 1843.12it/s]
# convert coverage to meters:  86%|█████████████████████████████████████████▎      | 3100/3601 [00:01<00:00, 1860.43it/s]
# convert coverage to meters:  92%|████████████████████████████████████████████    | 3301/3601 [00:01<00:00, 1851.50it/s]
# convert coverage to meters: 100%|████████████████████████████████████████████████| 3601/3601 [00:02<00:00, 1792.13it/s]
#
# Calculating damage:   0%|                                                                     | 0/3601 [00:00<?, ?it/s]
# Calculating damage:  37%|████████████████████▏                                  | 1324/3601 [00:00<00:00, 12056.52it/s]
# Calculating damage: 100%|███████████████████████████████████████████████████████| 3601/3601 [00:00<00:00, 13487.25it/s]
# Risk Calculation:  38%|████████████████████████▊                                         | 3/8 [03:28<05:48, 69.74s/it]
# Overlay raster with vector:   0%|                                                               | 0/18 [00:00<?, ?it/s]
# Overlay raster with vector:   6%|███                                                    | 1/18 [00:00<00:05,  2.90it/s]
# Overlay raster with vector:  11%|██████                                                 | 2/18 [00:02<00:19,  1.19s/it]
# Overlay raster with vector:  17%|█████████▏                                             | 3/18 [00:18<02:03,  8.24s/it]
# Overlay raster with vector:  22%|████████████▏                                          | 4/18 [00:19<01:16,  5.47s/it]
# Overlay raster with vector:  28%|███████████████▎                                       | 5/18 [00:23<01:03,  4.86s/it]
# Overlay raster with vector:  33%|██████████████████▎                                    | 6/18 [00:24<00:39,  3.30s/it]
# Overlay raster with vector:  39%|█████████████████████▍                                 | 7/18 [00:38<01:15,  6.90s/it]
# Overlay raster with vector:  44%|████████████████████████▍                              | 8/18 [00:46<01:11,  7.19s/it]
# Overlay raster with vector:  50%|███████████████████████████▌                           | 9/18 [00:51<01:00,  6.74s/it]
# Overlay raster with vector:  56%|██████████████████████████████                        | 10/18 [01:00<00:58,  7.30s/it]
# Overlay raster with vector:  61%|█████████████████████████████████                     | 11/18 [01:01<00:36,  5.25s/it]
# Overlay raster with vector:  72%|███████████████████████████████████████               | 13/18 [01:01<00:15,  3.01s/it]
# Overlay raster with vector:  78%|██████████████████████████████████████████            | 14/18 [01:07<00:14,  3.57s/it]
# Overlay raster with vector:  83%|█████████████████████████████████████████████         | 15/18 [01:07<00:08,  2.80s/it]
# Overlay raster with vector: 100%|██████████████████████████████████████████████████████| 18/18 [01:08<00:00,  3.83s/it]
#
# convert coverage to meters:   0%|                                                             | 0/4230 [00:00<?, ?it/s]
# convert coverage to meters:   5%|██▋                                              | 229/4230 [00:00<00:01, 2093.07it/s]
# convert coverage to meters:  12%|█████▊                                           | 502/4230 [00:00<00:01, 2324.70it/s]
# convert coverage to meters:  17%|████████▌                                        | 735/4230 [00:00<00:01, 2095.83it/s]
# convert coverage to meters:  22%|██████████▉                                      | 947/4230 [00:00<00:01, 1928.92it/s]
# convert coverage to meters:  27%|████████████▉                                   | 1142/4230 [00:00<00:01, 1708.92it/s]
# convert coverage to meters:  31%|██████████████▉                                 | 1317/4230 [00:00<00:01, 1603.23it/s]
# convert coverage to meters:  35%|████████████████▊                               | 1480/4230 [00:00<00:01, 1504.91it/s]
# convert coverage to meters:  39%|██████████████████▌                             | 1632/4230 [00:00<00:01, 1469.70it/s]
# convert coverage to meters:  42%|████████████████████▏                           | 1780/4230 [00:01<00:01, 1434.29it/s]
# convert coverage to meters:  45%|█████████████████████▊                          | 1924/4230 [00:01<00:01, 1341.56it/s]
# convert coverage to meters:  50%|████████████████████████                        | 2118/4230 [00:01<00:01, 1497.65it/s]
# convert coverage to meters:  54%|█████████████████████████▊                      | 2271/4230 [00:01<00:01, 1372.87it/s]
# convert coverage to meters:  58%|███████████████████████████▉                    | 2459/4230 [00:01<00:01, 1468.70it/s]
# convert coverage to meters:  63%|██████████████████████████████                  | 2651/4230 [00:01<00:01, 1548.91it/s]
# convert coverage to meters:  68%|████████████████████████████████▍               | 2863/4230 [00:01<00:00, 1660.21it/s]
# convert coverage to meters:  73%|███████████████████████████████████             | 3086/4230 [00:01<00:00, 1768.95it/s]
# convert coverage to meters:  79%|█████████████████████████████████████▋          | 3325/4230 [00:01<00:00, 1891.51it/s]
# convert coverage to meters:  83%|███████████████████████████████████████▉        | 3524/4230 [00:02<00:00, 1896.87it/s]
# convert coverage to meters:  88%|██████████████████████████████████████████▏     | 3715/4230 [00:02<00:00, 1899.24it/s]
# convert coverage to meters:  92%|████████████████████████████████████████████▎   | 3906/4230 [00:02<00:00, 1900.42it/s]
# convert coverage to meters: 100%|████████████████████████████████████████████████| 4230/4230 [00:02<00:00, 1749.93it/s]
#
# Calculating damage:   0%|                                                                     | 0/4230 [00:00<?, ?it/s]
# Calculating damage:  36%|███████████████████▉                                   | 1536/4230 [00:00<00:00, 13993.10it/s]
# Calculating damage: 100%|███████████████████████████████████████████████████████| 4230/4230 [00:00<00:00, 14163.91it/s]
# Risk Calculation:  50%|█████████████████████████████████                                 | 4/8 [04:43<04:47, 71.78s/it]
# Overlay raster with vector:   0%|                                                               | 0/18 [00:00<?, ?it/s]
# Overlay raster with vector:   6%|███                                                    | 1/18 [00:00<00:05,  2.88it/s]
# Overlay raster with vector:  11%|██████                                                 | 2/18 [00:02<00:19,  1.19s/it]
# Overlay raster with vector:  17%|█████████▏                                             | 3/18 [00:18<02:01,  8.12s/it]
# Overlay raster with vector:  22%|████████████▏                                          | 4/18 [00:19<01:13,  5.28s/it]
# Overlay raster with vector:  28%|███████████████▎                                       | 5/18 [00:23<01:00,  4.68s/it]
# Overlay raster with vector:  33%|██████████████████▎                                    | 6/18 [00:23<00:38,  3.18s/it]
# Overlay raster with vector:  39%|█████████████████████▍                                 | 7/18 [00:37<01:13,  6.72s/it]
# Overlay raster with vector:  44%|████████████████████████▍                              | 8/18 [00:43<01:04,  6.49s/it]
# Overlay raster with vector:  50%|███████████████████████████▌                           | 9/18 [00:48<00:54,  6.10s/it]
# Overlay raster with vector:  56%|██████████████████████████████                        | 10/18 [00:57<00:55,  6.90s/it]
# Overlay raster with vector:  61%|█████████████████████████████████                     | 11/18 [00:57<00:34,  4.94s/it]
# Overlay raster with vector:  72%|███████████████████████████████████████               | 13/18 [00:58<00:14,  2.84s/it]
# Overlay raster with vector:  78%|██████████████████████████████████████████            | 14/18 [01:03<00:13,  3.42s/it]
# Overlay raster with vector:  83%|█████████████████████████████████████████████         | 15/18 [01:04<00:08,  2.69s/it]
# Overlay raster with vector: 100%|██████████████████████████████████████████████████████| 18/18 [01:05<00:00,  3.64s/it]
#
# convert coverage to meters:   0%|                                                             | 0/4470 [00:00<?, ?it/s]
# convert coverage to meters:   4%|█▉                                               | 172/4470 [00:00<00:02, 1671.54it/s]
# convert coverage to meters:  10%|█████                                            | 466/4470 [00:00<00:01, 2278.24it/s]
# convert coverage to meters:  16%|███████▌                                         | 693/4470 [00:00<00:01, 2184.87it/s]
# convert coverage to meters:  20%|█████████▉                                       | 911/4470 [00:00<00:01, 2104.60it/s]
# convert coverage to meters:  25%|████████████                                    | 1122/4470 [00:00<00:01, 1764.79it/s]
/s]
# Calculating damage: 100%|███████████████████████████████████████████████████████| 5022/5022 [00:00<00:00, 13552.66it/s]
# Risk Calculation:  88%|█████████████████████████████████████████████████████████▊        | 7/8 [08:19<01:11, 71.91s/it]
# Overlay raster with vector:   0%|                                                               | 0/18 [00:00<?, ?it/s]
# Overlay raster with vector:   6%|███                                                    | 1/18 [00:00<00:05,  2.84it/s]
# Overlay raster with vector:  11%|██████                                                 | 2/18 [00:02<00:20,  1.28s/it]
# Overlay raster with vector:  17%|█████████▏                                             | 3/18 [00:18<02:01,  8.12s/it]
# Overlay raster with vector:  22%|████████████▏                                          | 4/18 [00:19<01:14,  5.32s/it]
# Overlay raster with vector:  28%|███████████████▎                                       | 5/18 [00:23<01:01,  4.71s/it]
# Overlay raster with vector:  33%|██████████████████▎                                    | 6/18 [00:23<00:38,  3.21s/it]
# Overlay raster with vector:  39%|█████████████████████▍                                 | 7/18 [00:37<01:12,  6.63s/it]
# Overlay raster with vector:  44%|████████████████████████▍                              | 8/18 [00:43<01:03,  6.38s/it]
# Overlay raster with vector:  50%|███████████████████████████▌                           | 9/18 [00:48<00:55,  6.18s/it]
# Overlay raster with vector:  56%|██████████████████████████████                        | 10/18 [00:56<00:53,  6.74s/it]
# Overlay raster with vector:  61%|█████████████████████████████████                     | 11/18 [00:57<00:33,  4.85s/it]
# Overlay raster with vector:  72%|███████████████████████████████████████               | 13/18 [00:58<00:13,  2.79s/it]
# Overlay raster with vector:  78%|██████████████████████████████████████████            | 14/18 [01:02<00:13,  3.25s/it]
# Overlay raster with vector:  83%|█████████████████████████████████████████████         | 15/18 [01:03<00:07,  2.57s/it]
# Overlay raster with vector: 100%|██████████████████████████████████████████████████████| 18/18 [01:04<00:00,  3.58s/it]
#
# convert coverage to meters:   0%|                                                             | 0/5464 [00:00<?, ?it/s]
# convert coverage to meters:   3%|█▍                                               | 164/5464 [00:00<00:03, 1492.35it/s]
# convert coverage to meters:   8%|███▉                                             | 438/5464 [00:00<00:02, 2082.03it/s]
# convert coverage to meters:  12%|█████▊                                           | 647/5464 [00:00<00:02, 1997.31it/s]
# convert coverage to meters:  16%|███████▌                                         | 847/5464 [00:00<00:02, 1807.19it/s]
# convert coverage to meters:  19%|█████████▎                                      | 1056/5464 [00:00<00:02, 1831.02it/s]
# convert coverage to meters:  23%|██████████▉                                     | 1241/5464 [00:00<00:02, 1702.78it/s]
# convert coverage to meters:  26%|████████████▍                                   | 1413/5464 [00:00<00:02, 1524.34it/s]
# convert coverage to meters:  29%|█████████████▊                                  | 1569/5464 [00:00<00:02, 1390.36it/s]
# convert coverage to meters:  31%|███████████████                                 | 1711/5464 [00:01<00:02, 1285.81it/s]
# convert coverage to meters:  35%|████████████████▌                               | 1890/5464 [00:01<00:02, 1379.47it/s]
# convert coverage to meters:  37%|█████████████████▊                              | 2031/5464 [00:01<00:02, 1350.94it/s]
# convert coverage to meters:  40%|███████████████████                             | 2168/5464 [00:01<00:02, 1321.58it/s]
# convert coverage to meters:  42%|████████████████████▏                           | 2302/5464 [00:01<00:02, 1276.79it/s]
# convert coverage to meters:  44%|█████████████████████▎                          | 2431/5464 [00:01<00:02, 1141.06it/s]
# convert coverage to meters:  49%|███████████████████████▎                        | 2653/5464 [00:01<00:02, 1364.57it/s]
# convert coverage to meters:  52%|████████████████████████▉                       | 2836/5464 [00:01<00:01, 1473.23it/s]
# convert coverage to meters:  55%|██████████████████████████▏                     | 2987/5464 [00:02<00:01, 1305.96it/s]
# convert coverage to meters:  58%|███████████████████████████▋                    | 3149/5464 [00:02<00:01, 1355.32it/s]
# convert coverage to meters:  61%|█████████████████████████████▎                  | 3336/5464 [00:02<00:01, 1467.30it/s]
# convert coverage to meters:  64%|██████████████████████████████▋                 | 3487/5464 [00:02<00:01, 1359.53it/s]
# convert coverage to meters:  68%|████████████████████████████████▍               | 3693/5464 [00:02<00:01, 1489.03it/s]
# convert coverage to meters:  71%|██████████████████████████████████              | 3878/5464 [00:02<00:01, 1536.16it/s]
# convert coverage to meters:  75%|████████████████████████████████████            | 4105/5464 [00:02<00:00, 1688.68it/s]
# convert coverage to meters:  78%|█████████████████████████████████████▌          | 4277/5464 [00:02<00:00, 1653.31it/s]
# convert coverage to meters:  83%|███████████████████████████████████████▋        | 4512/5464 [00:02<00:00, 1770.60it/s]
# convert coverage to meters:  86%|█████████████████████████████████████████▎      | 4708/5464 [00:03<00:00, 1780.70it/s]
# convert coverage to meters:  89%|██████████████████████████████████████████▉     | 4887/5464 [00:03<00:00, 1760.28it/s]
# convert coverage to meters:  93%|████████████████████████████████████████████▋   | 5086/5464 [00:03<00:00, 1816.84it/s]
# convert coverage to meters: 100%|████████████████████████████████████████████████| 5464/5464 [00:03<00:00, 1567.46it/s]
#
# Calculating damage:   0%|                                                                     | 0/5464 [00:00<?, ?it/s]
# Calculating damage:  24%|█████████████                                          | 1302/5464 [00:00<00:00, 11839.81it/s]
# Calculating damage:  50%|███████████████████████████▍                           | 2730/5464 [00:00<00:00, 13214.82it/s]
# Calculating damage: 100%|███████████████████████████████████████████████████████| 5464/5464 [00:00<00:00, 13514.49it/s]
# Risk Calculation: 100%|██████████████████████████████████████████████████████████████████| 8/8 [09:31<00:00, 71.38s/it]
# Risk Calculation: 100%|██████████████████████████████████████████████████████████████████| 8/8 [00:12<00:00,  1.51s/it]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'damage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 7
#       1 save_asset_risk_results = {}
#       2 for asset_type in asset_types:
#       3         save_asset_risk_results[asset_type] = DamageScanner(hazard_dict[2],
#       4                                                        infrastructure_path,
#       5                                                        curves=damage_curves_all_ci[asset_type],
#       6                                                        maxdam=maxdam_all_ci[asset_type]
# ----> 7                                                            ).risk(hazard_dict,
#       8             asset_type=asset_type
#       9         )
#
# File ~\.conda\envs\pygis\Lib\site-packages\damagescanner\core.py:183, in DamageScanner.risk(self, hazard_dict, **kwargs)
#     178 largest_rp = df_risk.loc[:, pd.IndexSlice[RP_list[-1],:]]
#     180 if kwargs.get("multi_curves", None) is None:
#     181
#     182     # only keep the damage values
# --> 183     df_risk = df_risk.loc[:, pd.IndexSlice[RP_list, 'damage']].fillna(0)
#     185     RPS = [1 / x for x in RP_list]
#     187     risk = pd.DataFrame(
#     188         df_risk.apply(
#     189             lambda x: integrate.simpson(y=x[RP_list][::-1], x=RPS[::-1]), axis=1
#     190         ),
#     191         columns=["tot_risk"],
#     192     )
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexing.py:1041, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1039 # we may have a nested tuples indexer here
#    1040 if self._is_nested_tuple_indexer(tup):
# -> 1041     return self._getitem_nested_tuple(tup)
#    1043 # we maybe be using a tuple to represent multiple dimensions here
#    1044 ax0 = self.obj._get_axis(0)
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1150     axis -= 1
#    1151     continue
# -> 1153 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1154 axis -= 1
#    1156 # if we have a scalar, we are done
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexing.py:1424, in _LocIndexer._getitem_axis(self, key, axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
# -> 1424     locs = labels.get_locs(key)
#    1425     indexer: list[slice | npt.NDArray[np.intp]] = [slice(None)] * self.ndim
#    1426     indexer[axis] = locs
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexes\multi.py:3536, in MultiIndex.get_locs(self, seq)
#    3532     continue
#    3534 else:
#    3535     # a slice or a single label
# -> 3536     lvl_indexer = self._get_level_indexer(k, level=i, indexer=indexer)
#    3538 # update indexer
#    3539 lvl_indexer = _to_bool_indexer(lvl_indexer)
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexes\multi.py:3391, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3388         return slice(i, j, step)
#    3390 else:
# -> 3391     idx = self._get_loc_single_level_index(level_index, key)
#    3393     if level > 0 or self._lexsort_depth == 0:
#    3394         # Desired level is not sorted
#    3395         if isinstance(idx, slice):
#    3396             # test_get_loc_partial_timestamp_multiindex
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexes\multi.py:2980, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2978     return -1
#    2979 else:
# -> 2980     return level_index.get_loc(key)
#
# File ~\.conda\envs\pygis\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'damage'

# %% [markdown]
# ## 5. Visualising the results

# %%
collect_damages = {}
for asset_type in asset_types:
    damage_results = save_asset_results[asset_type]
    if len(damage_results) == 0:
        continue
    else:
        collect_damages[asset_type] = damage_results.damage.sum()

# %%
colors = ['#66c2a5','#fc8d62','#8da0cb','#e78ac3','#a6d854','#ffd92f','#e5c494','#b3b3b3']

# %%
labels = [x.capitalize() for x in list(collect_damages.keys())]
sizes = collect_damages.values()
pie = plt.pie(sizes,autopct='%1.1f%%', labeldistance=1.15, wedgeprops = { 'linewidth' : 1, 'edgecolor' : 'white' }, colors=colors);
plt.axis('equal')
plt.legend(loc = 'right', labels=labels,bbox_to_anchor=(1.15, 0.5),)
plt.title(f'River Flood Damage for {country_full_name} for multiple \n Critical Infrastructure systems',fontweight='bold')
